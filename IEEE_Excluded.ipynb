# %%
import os
import shutil

import re
import time
import pandas as pd


csv_fileIEEE = pd.read_csv('Data-25May/IEEE-firsta.csv',header=0, engine='python', warn_bad_lines=True, error_bad_lines=False)
csv_fileIEEE_Excluded = pd.read_csv('Data-25May/IEEE_Excluded.csv',header=0, engine='python', warn_bad_lines=True, error_bad_lines=False)


csv_fileIEEE
# Out:
#                                          Document Title  \
# 0     An automatic evaluation of machine translation...
# 1     Automatic Machine Translation of Poetry and a ...
# 2     Automatic Machine Translation Evaluation Based...
# 3     Automatic identification and multi-translatabl...
# 4     Linguistic Structure Analysis of Thai and Whit...
# ...                                                 ...
# 1989  To have linguistic tree structures in statisti...
# 1990  2001 IEEE Workshop on Automatic Speech Recogni...
# 1991  2007 IEEE workshop on automatic speech recogni...
# 1992  Proceedings of 2002 International Conference o...
# 1993  Keynote speech: FPGA-based machine learning fo...
#
#                                                 Authors  \
# 0                                   D. Munkova; M. Munk
# 1                   I. DunÄ‘er; S. Seljan; M. Pavlovski
# 2     D. Ze-ya; Z. Han-fen; Z. Quan; M. Jian-ming; C...
# 3                                          J. Qu; Y. Lu
# ...

# %%
cond = csv_fileIEEE['Document Title'].isin(csv_fileIEEE_Excluded['Document Title'])
#csv_fileIEEE.drop(csv_fileIEEE[cond].index, inplace = True)
#csv_fileIEEE.reset_index(drop=True, inplace=True)
csv_fileIEEE[cond].to_excel("filter-25May\IEEE_eliminated.xlsx", index=False)
csv_fileIEEE[cond]
# Out:
#                                          Document Title  \
# 7             ASR Normalization for Machine Translation
# 13    Using Example-Based Machine Translation Method...
# 22    Classification techniques for automatic speech...
# 28    Syntax Rectification of Speech Using Neural Ma...
# 49    A Study of Myanmar (Burmese) to English Machin...
# ...                                                 ...
# 1979  aCortex: An Energy-Efficient Multipurpose Mixe...
# 1980  A novel brain computer interface based on Prin...
# 1983  Logistic regression classifier for palmprint v...
# 1986                 CW-SSIM based image classification
# 1990  2001 IEEE Workshop on Automatic Speech Recogni...
#
#                                            Authors  \
# 7             H. Huang; C. Feng; J. Wang; X. Zhang
# 13           Linsen Yu; Yongmei Liu; Tianwen Zhang
# 22             H. H. O. Nasereddin; A. A. R. Omari
# 28         J. Singh; S. Pote; A. Karhe; A. Agrawal
# ...

# %%
csv_fileIEEE.to_excel("filter-25May\IEEE_After_ExcludedTopics.xlsx", index=False)
csv_fileIEEE
# Out:
#                                         Document Title  \
# 0    Automatic Machine Translation of Poetry and a ...
# 1    Human Quality Evaluation of Machine-Translated...
# 2    A Summary and Comparative Study of Different M...
# 3    Statistical machine translation of Croatian we...
# 4    A hybrid approach for Hindi-English machine tr...
# ..                                                 ...
# 865  Multimodal Machine Learning: A Survey and Taxo...
# 866  Deep Learning for Proactive Network Monitoring...
# 867  On the Future of Information: Reunification, C...
# 868                  The object-oriented machine: DOOM
# 869  Using machine learning to focus iterative opti...
#
#                                                Authors  Publication Year  \
# 0                            A. A. Deshmukh; R. Prasad              2020
# 1    A. A. Suryani; D. H. Widyantoro; A. Purwariant...              2020
# 2    A. A. Zhivotova; V. D. Berdonosov; E. V. Redkolis              2018
# ...
