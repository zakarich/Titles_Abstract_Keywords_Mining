# %%
import os
import shutil

import re
import time
import pandas as pd
import numpy as np

import pprint
from ast import literal_eval


Corpus = pd.read_excel('CorpusBeta.xlsx', header=0)

Corpus['From-->Too'] = Corpus['From-->Too'].apply(literal_eval)
Corpus['Method Used'] = Corpus['Method Used'].apply(literal_eval)

print('la taille de la corpus : '+str(len(Corpus)))
Corpus
# Out:
# la taille de la corpus : 2014
#                                                   Title  \
# 0     Matching graph, a method for extracting parall...
# 1     Machine translation errors: English and Iraqi ...
# 2     An automatic and a machine-assisted method to ...
# 3     Combining MEDLINE and publisher data to create...
# 4     Syntax-based Chinese-Vietnamese tree-to-tree s...
# ...                                                 ...
# 2009  Machine translation architecture based on micr...
# 2010  Uyghur-Chinese translation disambiguation meth...
# 2011  Application and analysis of string-similarity-...
# 2012  A comparative study on applying hierarchical p...
# 2013  OpenMaTrEx: A free/open-source marker-driven e...
#
#                                                Abstract  \
# 0     Comparable corpora are valuable alternatives f...
# 1     Errors in machine translations of English-Iraq...
# 2     Two different methods of corpus cleaning are p...
# 3     Background: Most of the institutional and rese...
# 4     Because of the scarcity of bilingual corpora, ...
# ...                                                 ...
# 2009  This paper surveys current approaches of multi...
# 2010  This thesis studies the disambiguation method ...
# 2011  To help developing a localization-oriented exa...
# 2012  To set an appropriate goal of SMT research for...
# 2013  We describe OpenMaTrEx, a free/open-source exa...
#
#                                         Author Keywords  \
# 0     And Arabic languages; Comparable corpora; Engl...
# 1     Arabic; English; Error analysis; Evaluation; S...
# 2     Bilingual corpus cleaning; Statistical machine...
# 3     Biomedical domain; Multilingual corpus generat...
# 4     Chinese-Vietnamese; Linguistic features; Pruni...
# ...                                                 ...
# 2009  Machine translation; Micro-engine pipeline; Mu...
# 2010  Knowledge automatic-acquisition; Uyghur-chines...
# 2011  Correlation; Linear regression; Machine transl...
# 2012  Hierarchical phrase-based translation; SMT; Th...
# 2013  corpus-based machine translation; example-base...
#
#                                                    Link  Year  Cited by  \
# 0     https://www.scopus.com/inward/record.uri?eid=2...  2019       NaN
# 1     https://www.scopus.com/inward/record.uri?eid=2...  2011       1.0
# 2     https://www.scopus.com/inward/record.uri?eid=2...  2019       NaN
# 3     https://www.scopus.com/inward/record.uri?eid=2...  2013      14.0
# 4     https://www.scopus.com/inward/record.uri?eid=2...  2019       1.0
# ...                                                 ...   ...       ...
# 2009  https://www.scopus.com/inward/record.uri?eid=2...  2004       NaN
# 2010  https://www.scopus.com/inward/record.uri?eid=2...  2015       NaN
# 2011  https://www.scopus.com/inward/record.uri?eid=2...  2004       NaN
# 2012  https://www.scopus.com/inward/record.uri?eid=2...  2012       1.0
# 2013  https://www.scopus.com/inward/record.uri?eid=2...  2010       9.0
#
#      Page start Page end Page count                           DOI  \
# 0           NaN      NaN          1               10.1145/3329713
# 1           NaN      NaN          1       10.1145/1929908.1929910
# 2           NaN      NaN          1               10.1145/3342351
# 3           NaN      NaN          1      10.1186/1471-2105-14-146
# 4           NaN      NaN          1               10.1145/3314938
# ...         ...      ...        ...                           ...
# 2009        651      658          8                           NaN
# 2010        NaN      NaN          6                           NaN
# 2011       1258     1265          8                           NaN
# 2012        126      133          8         10.1109/KICSS.2012.23
# 2013        121      126          6  10.1007/978-3-642-14770-8_15
#
#                                                 Authors     Document Type  \
# 0               Bakhshaei S., Safabakhsh R., Khadivi S.           Article
# 1     Condon S., Parvaz D., Aberdeen J., Doran C., F...           Article
# 2             Srivastava J., Sanyal S., Srivastava A.K.           Article
# 3          Jimeno Yepes A., Prieur-Gaston É., Névéol A.           Article
# 4     Gao S., Huang J., Xue M., Yu Z., Wang Z., Zhan...           Article
# ...                                                 ...               ...
# 2009                                             Liu Q.           Article
# 2010                            Ge R., Yong Y., Chun X.           Article
# 2011              Yao J.-M., Zhou M., Zhao T.-J., Li S.           Article
# 2012  Luekhong P., Sukhauta R., Porkaew P., Ruangraj...  Conference Paper
# 2013  Dandapat S., Forcada M.L., Groves D., Penkale ...  Conference Paper
#
#       Source                  From-->Too    Method Used is it a survey?
# 0     Scopus  [persian, arabic, english]  [statistical]              []
# 1     Scopus           [arabic, english]  [statistical]              []
# 2     Scopus            [hindi, english]  [statistical]              []
# 3     Scopus  [spanish, french, english]  [statistical]              []
# 4     Scopus       [vietnamese, chinese]  [statistical]              []
# ...      ...                         ...            ...             ...
# 2009  Scopus          [chinese, english]             []              []
# 2010  Scopus           [uyghur, chinese]             []              []
# 2011  Scopus                          []             []              []
# 2012  Scopus             [chinese, thai]             []              []
# 2013  Scopus                          []             []              []
#
# [2014 rows x 16 columns]

# %%
Corpus.drop(Corpus.index[Corpus['Year'] == 2021.0], inplace = True)
Corpus.drop(Corpus.index[Corpus['Year'] == 2022.0], inplace = True)

#Corpus['Year'] = Corpus['Year'].astype(int)


groupedCorpus = Corpus.groupby('Year')
gr_Corpus = groupedCorpus.count()

df = pd.DataFrame()

df['YEAR'] = gr_Corpus.index.values
df['Count'] = gr_Corpus['Title'].values

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.style.use('ggplot')
#figure(figsize = (25, 18), dpi = 100)
#Get current axis 
#fig = plt.gcf() # get current figure
# line plot for math marks 
df.plot(kind = 'bar', 
        x = 'YEAR')

# set the title 
plt.title('research evolution per year') 
plt.savefig('media/NumberOfArticlesPerYear.png', dpi = 500)
  
# show the plot 
plt.show()

# %%
Corpus['Document Type'].value_counts()
# Out:
# Conference Paper    977
# Article             746
# IEEE Conferences    124
# Book Chapter         30
# IEEE Journals        29
# Review                9
# TUP Journals          1
# IET Conferences       1
# Name: Document Type, dtype: int64

# %%
Corpus['Document Type'] = Corpus['Document Type'].replace(['Article','IEEE Journals','TUP Journals','Journals'],'Journal')
Corpus['Document Type'] = Corpus['Document Type'].replace(['IET Conferences','IEEE Conferences'],'Conference Paper')
Corpus['Document Type'].value_counts()
# Out:
# Conference Paper    1102
# Journal              776
# Book Chapter          30
# Review                 9
# Name: Document Type, dtype: int64

# %%
colors = ( "orange", "cyan", "brown","grey", "indigo", "beige")
Corpus['Document Type'].value_counts().plot(kind='pie',colors = colors)
# Out:
# <AxesSubplot:ylabel='Document Type'>
