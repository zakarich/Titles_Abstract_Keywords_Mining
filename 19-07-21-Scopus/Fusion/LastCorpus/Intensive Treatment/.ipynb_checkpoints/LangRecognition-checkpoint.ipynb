# %%
import os
import shutil

import re
import time
import pandas as pd

#csv_file = pd.read_csv('Data/ALL-export2021.01.24.csv',header=0)
#csv_file = pd.read_csv('Data/Scopus-DB.csv',header=0, engine='python', warn_bad_lines=True, error_bad_lines=False)

#df = pd.DataFrame(csv_file[["Document Title","Authors","Abstract","DOI","Publication Year","Library"]])
#df = pd.DataFrame(csv_file[["Title","Author","Abstract Note","DOI","Publication Year","Library"]])

#excel_file = pd.read_excel('Data/IEEE.xlsx')
excel_file = pd.read_excel('Data/SCOPUS.xlsx')

#df = pd.DataFrame(excel_file[["Document Title","Authors","Abstract","DOI","Publication Year","Library"]])
df = pd.DataFrame(excel_file[["Title","Author","Abstract Note","DOI","Publication Year","Library"]])

#df.to_excel("reporting\IEEE.xlsx", index=False)
df.to_excel("reporting\SCOPUS.xlsx", index=False)
df
# Out:
#                                                  Title  \
# 0    Improving neural machine translation with POS ...
# 1    Transformer encoders incorporating word transl...
# 2    Language Model Pre-training Method in Machine ...
# 3    Similarity-aware neural machine translation: r...
# 4    Machine translation testing via pathological i...
# ..                                                 ...
# 973  A perspective on machine translation: Theory a...
# 974   Steps Toward Knowledge-Based Machine Translation
# 975  The role of USAF research and development in i...
# 976  The trial translator, an automatic programming...
# 977         Structural analysis in machine translation
#
#                                                 Author  \
# 0    Nguyen, L.H.B.; Minh, H.D.; Dinh, D.; Le Manh, T.
# 1         Nguyen, T.; Nguyen, T.; Nguyen, H.; Tran, P.
# 2           Li, Z.; Qu, D.; Xie, C.; Zhang, W.; Li, Y.
# 3              Zhang, T.; Huang, H.; Feng, C.; Wei, X.
# 4               Gupta, S.; He, P.; Meister, C.; Su, Z.
# ..                                                 ...
# 973                                  Tucker, A.B., Jr.
# 974  Carbonell, J.G.; Cullingford, R.E.; Gershman, ...
# 975                                       Samson, R.F.
# 976                                     Giuliano, V.E.
# 977                                      Zarechnak, M.
#
#                                          Abstract Note  \
# 0    Neural Machine Translation (NMT) has certain c...
# 1    Neural machine translation systems including t...
# 2    Neural Machine Translation (NMT) model has bec...
# 3    In computer-aided translation tasks, reducing ...
# 4    Machine translation software has become heavil...
# ..                                                 ...
# 973                                                NaN
# 974  This paper considers the possibilities for kno...
# 975  The United States Air Force has numerous and v...
# 976  Grammatical and syntactic rules designed for t...
# 977  One of the research units of the current Georg...
#
#                             DOI  Publication Year Library
# 0     10.24507/icicelb.12.01.91              2021  SCOPUS
# 1     10.24507/icicelb.12.01.35              2021  SCOPUS
# 2     10.1142/S0218213020400217              2020  SCOPUS
# 3    10.1007/s00521-020-04939-y              2020  SCOPUS
# 4       10.1145/3368089.3409756              2020  SCOPUS
# ..                          ...               ...     ...
# 973       10.1145/358027.358035              1984  SCOPUS
# 974  10.1109/TPAMI.1981.4767124              1981  SCOPUS
# 975     10.1145/1457838.1457849              1959  SCOPUS
# 976     10.1145/1458043.1458072              1958  SCOPUS
# 977       10.1145/610937.610992              1958  SCOPUS
#
# [978 rows x 6 columns]

# %%
#df["Author Keywords"][569]

# %%
Languages_Translation = []
i","Romanian","Tagalog","Dutch","Amharic","Putonghua","Pashto","Magahi","Thai","Saraiki","Khmer","Chhattisgarhi","Somali","Malaysian","Malay","Cebuano","Nepali","Mesopotamian","Avar","Assamese","Sinhalese","Kurdish","Hejazi","Nigerian","Fulfulde","Bavarian","Azerbaijani","Greek","Chittagonian","Kazakh","Deccan","Hungarian","Kinyarwanda","Zulu","Levantine","Tunisian","Sanaani","MinBei","Bei","Rundi","Czech","Taʽizzi-Adeni","Uyghur","MinDong","Dong","Sylheti"]
Lang = [word.lower() for word in Languages]
for i in range(len(df["Abstract"])): 
    #res = re.sub(r'[^\w\s]', ' ', df.astype(str)["Document Title"][i]+df.astype(str)["Abstract"][i]+df.astype(str)["Author Keywords"][i])
    res = re.sub(r'[^\w\s]', ' ', str(df["Abstract"][i]))
    Abstract = res.lower().split() 
    Languages_Translation.append(list(set(Abstract) & set(Lang)))
df["From-->Too"] = Languages_Translation 
print("The number of languages that we could recognize :"+str(len(Lang)))
# Out:
# The number of languages that we could recognize :333

# %%
#df["From-->Too"] = Languages_Translation 
dfif = df[df.astype(str)["From-->Too"] == '[]']
dfof = df[df.astype(str)["From-->Too"] != '[]']
dfof.reset_index(drop=True, inplace=True)
dfif.reset_index(drop=True, inplace=True)
#dfif['Abstract'][170]

# %%
from re import search
#df[df.astype(str)["From --> Too"] != '[]']
#df_ar = dfof[dfof["From-->Too"].str.contains(r"arabic")]
df_ar = dfof[pd.DataFrame(dfof["From-->Too"].tolist()).isin(['arabic']).any(1).values]
df_en = dfof[pd.DataFrame(dfof["From-->Too"].tolist()).isin(['english']).any(1).values]
df_fr = dfof[pd.DataFrame(dfof["From-->Too"].tolist()).isin(['french']).any(1).values]
print("################################################################################")
print("################################################################################")
print("the number of articles that talk about machine translation and do not mention a specific language :"+str(len(dfif)))
print("################################################################################")
print("################################################################################")
print("the totale number of articles that talks about Machine Translation (From --> to) :"+str(len(dfof)))
print("################################################################################")
print("################################################################################")
print("the number of articles that talks about Arabic Machine Translation :"+str(len(df_ar)))
print("################################################################################")
print("################################################################################")
print("the number of articles that talks about English Machine Translation :"+str(len(df_en)))
print("################################################################################")
print("################################################################################")
print("the number of articles that talks about French Machine Translation :"+str(len(df_fr)))
print("################################################################################")
print("################################################################################")
# Out:
# ################################################################################
# ################################################################################
# the number of articles that talk about machine translation and do not mention a specific language :179
# ################################################################################
# ################################################################################
# the totale number of articles that talks about Machine Translation (From --> to) :391
# ################################################################################
# ################################################################################
# the number of articles that talks about Arabic Machine Translation :25
# ################################################################################
# ################################################################################
# the number of articles that talks about English Machine Translation :260
# ################################################################################
# ################################################################################
# the number of articles that talks about French Machine Translation :23
# ################################################################################
# ################################################################################

# %%
df_ar.to_excel("rest\MT_ar.xlsx", index=False)
df_en.to_excel("rest\MT_en.xlsx", index=False)
df_fr.to_excel("rest\MT_fr.xlsx", index=False)
dfof.to_excel("rest\MT_dfof.xlsx", index=False)
dfif.to_excel("rest\MT_dfif.xlsx", index=False)
len(dfof)+len(dfif)
# Out:
# 570
