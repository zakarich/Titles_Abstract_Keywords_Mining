# %%
import os
import shutil

import re
import time
import pandas as pd

excel_file = pd.read_excel('IEEE+SCOPUS+SPRINGER.xlsx')

excel_file
# Out:
#                                                   Title  \
# 0     Improving neural machine translation with POS ...
# 1     Transformer encoders incorporating word transl...
# 2     Language Model Pre-training Method in Machine ...
# 3     Similarity-aware neural machine translation: r...
# 4     Machine translation testing via pathological i...
# ...                                                 ...
# 2259  Regression for machine translation evaluation ...
# 2260  Optimizing segmentation granularity for neural...
# 2261  Multi-Modality for Interactive Machine Transla...
# 2262  Measuring machine translation quality as seman...
# 2263  Online discriminative learning for machine tra...
#
#                                                 Authors  \
# 0     Nguyen, L.H.B.; Minh, H.D.; Dinh, D.; Le Manh, T.
# 1          Nguyen, T.; Nguyen, T.; Nguyen, H.; Tran, P.
# 2            Li, Z.; Qu, D.; Xie, C.; Zhang, W.; Li, Y.
# 3               Zhang, T.; Huang, H.; Feng, C.; Wei, X.
# ...

# %%
type(excel_file)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
#Get current axis 
ax = plt.gca()  
  
# line plot for math marks 
excel_file.plot(kind = 'line', 
        x = 'Publication Year', 
        y = count(x), 
        color = 'green',ax = ax) 
  
# line plot for physics marks 
excel_file.plot(
    kind = 'line',
    x = 'Publication Year', 
    y = count(x), 
    color = 'blue',ax = ax) 
  
# line plot for chemistry marks 
excel_file.plot(kind = 'line',x = 'Publication Year', 
        y = count(x), 
        color = 'black',ax = ax) 
  
# set the title 
plt.title('LinePlots') 
  
# show the plot 
plt.show()
